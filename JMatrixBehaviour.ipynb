# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Our Calculated J matrix

# %%
J_mat = np.load("mouse599975_sweep1_param70_J_2000iters.npy")
#To look at the distributed of values in the interaction matrix

# %%
plt.hist(J_mat.flatten(), bins=30)
plt.yscale("log")
plt.xlabel("J Matrix Values bins")
plt.ylabel("No of values in the bin")
# Out:
# Text(0, 0.5, 'No of values in the bin')
